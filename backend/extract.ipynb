# %%
# !pip install langchain langchain-community langchain-google-genai chromadb
# !pip install pypdf pandas streamlit python-dotenv
# Out:
# Requirement already satisfied: langchain in .\myenv\lib\site-packages (1.0.8)
# Requirement already satisfied: langchain-community in .\myenv\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-google-genai in .\myenv\lib\site-packages (3.1.0)
# Requirement already satisfied: chromadb in .\myenv\lib\site-packages (1.3.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in .\myenv\lib\site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in .\myenv\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\myenv\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in .\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (0.4.46)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in .\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in .\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in .\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in .\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in .\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in .\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in .\myenv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in .\myenv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in .\myenv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in .\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in .\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (0.25.0)
# Requirement already satisfied: anyio in .\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in .\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in .\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in .\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in .\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in .\myenv\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in .\myenv\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\myenv\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in .\myenv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in .\myenv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in .\myenv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in .\myenv\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in .\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\myenv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\myenv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in .\myenv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in .\myenv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in .\myenv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\myenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in .\myenv\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.9.0 in .\myenv\lib\site-packages (from langchain-google-genai) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in .\myenv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in .\myenv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in .\myenv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in .\myenv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in .\myenv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (6.33.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in .\myenv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in .\myenv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in .\myenv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in .\myenv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in .\myenv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in .\myenv\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: build>=1.0.3 in .\myenv\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in .\myenv\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in .\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in .\myenv\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in .\myenv\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in .\myenv\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in .\myenv\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in .\myenv\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in .\myenv\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in .\myenv\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in .\myenv\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in .\myenv\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in .\myenv\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: bcrypt>=4.0.1 in .\myenv\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in .\myenv\lib\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in .\myenv\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in .\myenv\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in .\myenv\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in .\myenv\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in .\myenv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in .\myenv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in .\myenv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in .\myenv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: pyproject_hooks in .\myenv\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in .\myenv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\myenv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\myenv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in .\myenv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in .\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in .\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in .\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in .\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in .\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: sympy in .\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in .\myenv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in .\myenv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in .\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in .\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in .\myenv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\myenv\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\myenv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in .\myenv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.1.5)
# Requirement already satisfied: filelock in .\myenv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\myenv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in .\myenv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: shellingham in .\myenv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.4)
# Requirement already satisfied: typer-slim in .\myenv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.20.0)
# Requirement already satisfied: click>=8.0.0 in .\myenv\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in .\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in .\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in .\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in .\myenv\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in .\myenv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in .\myenv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in .\myenv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\myenv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pypdf in .\myenv\lib\site-packages (6.3.0)
# Requirement already satisfied: pandas in .\myenv\lib\site-packages (2.3.3)
# Requirement already satisfied: streamlit in .\myenv\lib\site-packages (1.51.0)
# Requirement already satisfied: python-dotenv in .\myenv\lib\site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.26.0 in .\myenv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in .\myenv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in .\myenv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in .\myenv\lib\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in .\myenv\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: packaging<26,>=20 in .\myenv\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in .\myenv\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in .\myenv\lib\site-packages (from streamlit) (6.33.1)
# Requirement already satisfied: pyarrow<22,>=7.0 in .\myenv\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in .\myenv\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in .\myenv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in .\myenv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in .\myenv\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in .\myenv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in .\myenv\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in .\myenv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in .\myenv\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in .\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in .\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in .\myenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.12.0)
# Requirement already satisfied: colorama in .\myenv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in .\myenv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in .\myenv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in .\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in .\myenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: MarkupSafe>=2.0 in .\myenv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in .\myenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.29.0)
# Requirement already satisfied: six>=1.5 in .\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma

from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

from dotenv import load_dotenv
import os

# %%
import tempfile 
import pandas as pd
from dotenv import load_dotenv
import streamlit as st

load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
Google_api_key = os.environ.get("GOOGLE_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(temperature=0, model="gemini-2.5-flash", api_key=Google_api_key)
llm.invoke("tell me a joke")
# Out:
# AIMessage(content="Why don't scientists trust atoms?\n\nBecause they make up everything!", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--981a0eb8-a600-49a5-b192-dff34790746a-0', usage_metadata={'input_tokens': 5, 'output_tokens': 637, 'total_tokens': 642, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 622}})

# %%
### load
loader = PyPDFLoader("deepak_seminar.pdf")
pages = loader.load()
pages
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='1 \n \nA Seminar Report \n on \n \n“Automatic Weather Observation System (AWOS)” \n \nSubmitted to the  \nSavitribai Phule Pune University  \nIn partial fulfillment for the award of the Degree of \nBachelor of Engineering  \nin \nInformation Technology \nby \nDeepak Kumar \nRoll No: 4318 \nClass: TE-IT(A)  \n \n \nUnder the guidance of \n \nDr. Ashwini Sapkal \n \nDepartment of Information Technology \nArmy Institute of Technology, \nDighi Hills, Pune - 411 015. \n \n2025-2026'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 1, 'page_label': '2'}, page_content='2 \n \n \nCERTIFICATE \n \nThis is to certify that the seminar report entitled “Automatic Ocean Observation System(AWOS)” \nbeing submitted by Deepak Kumar  (4318 / TE-IT(A)) is a record of bonafide work carried out by \nhim/her under the supervision and guidance of Dr. Ashwini Sapkal in partial fulfillment of the \nrequirement for TE (Information Technology Engineering) – 2019 course of Savitribai Phule Pune \nUniversity, Pune in the academic year 2025-2026. \n \nDate:         \n \nPlace: Pune         \n \n \n \n \n \n \n             Guide                                                 Head of the Department \n \n \n \n \nPrincipal \n \n \nThis Seminar report has been examined by us as per the Savitribai Phule Pune University, Pune \nrequirements at Army Institute of Technology, Pune – 411015 on . . . . . . . . . . . \n \n \n \nInternal \nExaminer \n                                                                                 External \nExaminer'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 2, 'page_label': '3'}, page_content='3 \n \n \nAKNOWLEDGEMENT \n \n \nI would like to express my sincere gratitude to all those who contributed to the \nsuccessful completion of my seminar project titled “Automatic Ocean Observation \nSystem”. \n \nFirst and foremost, I wish to extend my heartfelt thanks to my project guide, Dr. \nAshwini Sap kal for her constant supervision, valuable suggestions, and expert \nguidance throughout the course of this work. Her continuous support and technical \nadvice were instrumental in shaping this project and deepening my understanding \nof use of AL/ML in ocean observation. \n \nI am also thankful to the Head of the Department, Dr. Sangeeta Jadhav , \nDepartment of Information Technology, Army Institute of Technology , for \nproviding the necessary facilities and academic support required to complete this \nseminar successfully. \n \nMy sincere appreciation goes to all the faculty members of the Department of \nInformation Technology  for their cooperation, encouragement, and helpful \nfeedback at various stages of the research and report preparation. \n \nI also acknowledge the contribution of the technical and laboratory staff  who \nassisted with computational resources and software environments used during \nexperimentation and model evaluation. \n \nThis acknowledgment is a humble expression of my appreciation for all the \nindividuals and institutions whose guidance, facilities, and cooperation made this \nseminar work possible. \n \n(Deepak Kumar) \n4318'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 3, 'page_label': '4'}, page_content='4 \n \n \nCONTENTS \n                                                                                                 \nSr.No TITLE Page no \n1. Introduction 7 \n2. Literature Survey 8 \n3. Motivation, Purpose, Scope and Objective 11 \n4. Methodology and Algorithm 13 \n5. Discussion and Conclusions 16 \n6. References 18'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 4, 'page_label': '5'}, page_content='5 \n \nABSTRACT \n \n \nThe Automatic Weather Observation System (AWOS) has emerged as a transformative \ntechnology in the field of meteorology and environmental monitoring, enabling the autonomous \ncollection and transmission of weather data with minimal human intervention. This review paper \nexamines the design principles, operational mechanisms, and technological advancements that \nhave contributed to the development of AWOS, with particular emphasis on its applications in \nmarine and atmospheric observation. AWOS integrates advanced sensor networks, IoT \ncommunication, and satellite-based data transmission to deliver continuous, high-accuracy \nmeasurements of key meteorological parameters such as temperature, humidity, air pressure, and \nwind speed. \n \nThe Automatic Weather Observation System (AWOS) has emerged as a transformative \ntechnology in the field of meteorology and environmental monitoring, enabling the autonomous \ncollection and transmission of weather data with minimal human intervention. This review paper \nexamines the design principles, operational mechanisms, and technological advancements that \nhave contributed to the development of AWOS, with particular emphasis on its applications in \nmarine and atmospheric observation. AWOS integrates advanced sensor networks, IoT \ncommunication, and satellite-based data transmission to deliver continuous, high-accuracy \nmeasurements of key meteorological parameters such as temperature, humidity, air pressure, and \nwind speed.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 5, 'page_label': '6'}, page_content='6 \n \nLIST OF FIGURES \n \n \n \nSr.No Figure Name Page no \n1. Architecture Diagram 15 \n2. ML pipeline for data transformation 17 \n \n \n \n \n \nLIST OF TABLES \n \nSr.No Table Name Page no \n1. Literature Survey - Review of Papers 9'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 6, 'page_label': '7'}, page_content='7 \n \n1. INTRODUCTION \n \nThe Automatic Weather Observation System (AWOS) is an advanced technology \ndesigned to automatically monitor and record key meteorological parameters \nsuch as temperature, humidity, pressure, and wind speed. Unlike traditional \nmanual methods, AWOS operates continuously with high accuracy and real-time \ndata transmission. It plays a vital role in improving weather forecasting, climate \nresearch, aviation safety, and marine navigation by ensuring reliable and \ncontinuous observation in all environmental conditions. \n \nThe Automatic Weather Observation System (AWOS) integrates high-precision \nsensors, IoT communication technologies, and satellite networks to automatically \nmeasure and transmit key parameters such as temperature, humidity, pressure, \nand wind speed. Designed for reliable operation in remote and harsh \nenvironments, it enables real-time monitoring and supports improved weather \nforecasting, early warning systems, and climate research by providing accurate \nand continuous atmospheric data. \n \nIn recent years, advancements in artificial intelligence (AI), edge computing, and \nrenewable energy systems have further enhanced the performance and efficiency \nof AWOS. AI-based algorithms enable intelligent data processing, error correction, \nand predictive analysis, while renewable energy sources such as solar and wave \npower ensure long-term, maintenance-free operation. The integration of AWOS \nwith global observation networks and satellite systems has expanded its \napplications beyond conventional weather monitoring to include marine \necosystem management, climate change studies, and disaster preparedness. \n \nThis study provides a comprehensive review of the architecture, components, \ncommunication frameworks, and analytical capabilities of AWOS. It also discusses \ncurrent challenges, recent technological advancements, and future research \ndirections aimed at improving the scalability, data accuracy, and sustainability of \nautomated weather observation systems.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 7, 'page_label': '8'}, page_content='8 \n \n2. LITERATURE SURVEY  \nThe field of ocean and weather observation has evolved significantly — \nfrom manual data collection to fully autonomous, AI-driven systems \ncapable of operating in remote and extreme environments. \n• Manual and Ground-Based Observation: Early weather monitoring \nrelied on human-operated instruments and fixed ground stations. \nWhile reliable for localized data, these systems lacked spatial \ncoverage, consistency, and real-time accessibility. \n• Automated Sensor Networks: The introduction of automated \nweather stations and buoys enabled continuous data collection \nwithout constant human presence. However, these systems were \nlimited in data transmission speed and long-term sustainability, \nespecially in marine conditions. \n• AI and Machine Learning Integration: Modern AWOS now utilize AI \nfor data analysis, anomaly detection, and predictive modeling. \nMachine learning enhances calibration, error correction, and \nforecasting accuracy, improving efficiency by up to 40% compared to \ntraditional methods. \n• Autonomous and Sustainable Observation Systems: The latest \nsystems combine AI, IoT, renewable energy, and autonomous \nvehicles (AUVs, gliders, and robotic buoys) to achieve long-term, self-\nsustaining ocean observation. These next-generation platforms \nsupport global climate monitoring, disaster prediction, and adaptive \nenvironmental management. \nThis evolution from manual observation to intelligent, autonomous systems \nunderscores the growing importance of integrating technology for precise, \nsustainable, and scalable weather and ocean monitoring.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 8, 'page_label': '9'}, page_content='9 \n \nA review of several key papers highlights this progression: \nSr.\nNo \nPaper \nName/title \nAuthor \nName/Ye\nar \nMethodology Future \nScope/shortcomi\nngs \nResults \n1. Ocean \nObservation \nTechnologies: \nA Review  \nMingwei \nLin , \nCanjun \nYang  \n ocean observation \ntechnologies from \nsurface to seafloor \n-Analyzed \napplications and \ndeployment \nmethods of each \ntechnology \nEmphasized the \nneed for more \nsustainable and \nefficient ocean \nobservation \nsystems.  \nDiscussed the \nintegration of \ndocking \ntechnology and \nsustained ocean \nenergy.  \n2. Future Vision \nfor \nAutonomous \nOcean \nObservations  \nChristoph\ner Whitt, \nJay \nPearlman \n2020  \nExamined current \nand emerging \nautonomous ocean \nobservation \ntechnologies and \nplatforms.  \nIncrease \ncooperation and \nstandardization \nin ocean \nobserving \nsystems.  \nEstimated 30–\n40% \nimprovement in \ndata collection \nefficiency using \nautonomous \nplatforms over \ntraditional \nmethods. \n3. Advanced \nSensing \nTechnology \nfor Ocean \nObservation  \nFederico \nAngelini, \n2025  \nFocused on signal \nprocessing, AI, and \nmachine learning \nfor marine data \nanalysis.  \nDevelop next-\ngeneration \nsensing \ntechnologies to \nimprove ocean \nobservation \ncapabilities. \n20–30% \nimprovement in \nmeasurement \nresolution and \ndata accuracy. \n- Effective on \nlarge \nimbalanced \ndatasets \n4. A Smart \nOcean \nObservation \nSystem for \nC. Sætre, \net al. \n2023  \n-Designed a smart \nocean observation \nsystem for real-\nExpand real-time \nmonitoring to \ncover larger \nAchieved up to \n40% increase in \ndata collection \nreliability'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 9, 'page_label': '10'}, page_content='10 \n \nReliable Real-\nTime \nMeasurement\ns \nthrough Deep \nLearning \ntime data \nacquisition \n-Discussed the \nclassification, \ndesign, and \ndeployment of \nmarine data buoys  \nocean areas and \ndeeper depths. \ncompared to \ntraditional \nbuoys.  \n5. Collaborative \nAutomation \nand IoT \nTechnologies \nfor Coastal \nOcean \nObserving \nSystems \n \nM. C. \nSorensen, \n2021 \n \nImplemented IoT-\nbased solutions, \nmachine-to-\nmachine \ncommunication, \nand data fusion \ntechniques. \n-Analyzed \nchallenges in \nsustained coastal \nocean \nobservations. \nPromote \nwidespread \nadoption of \ncollaborative \nautomation and \nIoT in coastal \nocean systems \nAchieved ~25% \nimprovement in \nobservation \nefficiency using \ncollaborative \nIoT systems. \n6. Advancing \nOcean \nObservation \nwith an AI-\nDriven Mobile \nRobotic \nExplorer \n \nH. \nHemming\ns et al, \n2020 \n \nDeveloped a \nmobile robotic tool \nequipped with \nintelligent onboard \nsampling \ncapabilities. \n-Integrated \nmachine learning \ntechniques to \ncharacterize upper \nwater column \nbiota by targeting \nspecific \nmesoplankton \ntaxa. \nExpand the \napplication of AI-\ndriven mobile \nrobotic explorers \nto other marine \necosystems. \n-Improve the \nadaptability and \nscalability of the \ntechnology for \nbroader \noceanographic \nstudies. \n \n- Enhanced \nobservation \nefficiency by \nreducing data \nprocessing time \nby \napproximately \n30%.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 10, 'page_label': '11'}, page_content='11 \n \n3.MOTIVATION, PURPOSE , SCOPE AND \nOBJECTIVE OF SEMINAR  \n \n \nMOTIVATION AND PURPOSE (PROBLEM STATEMENT) \nAccurate and continuous weather observation is essential for effective \nforecasting, marine safety, climate research, and disaster preparedness. However, \ntraditional observation methods and ground-based systems face major limitations \nin coverage, data consistency, and real-time accessibility \n• Limited Spatial and Temporal Coverage: Conventional observation stations \nare often restricted to land or coastal areas, leaving vast oceanic regions \nunmonitored. \n• Dependence on Manual Operation: Traditional weather monitoring \nrequires frequent maintenance and human supervision, making continuous \ndata collection difficult in remote or harsh conditions. \n• Data Inaccuracy under Dynamic Conditions: Sea conditions, sensor drift, \nand environmental interference can degrade measurement accuracy over \ntime, reducing the reliability of collected data. \n• Lack of Real-Time Data Transmission: Delayed or disrupted communication \nin remote areas prevents timely access to critical weather information \nneeded for forecasting and early warnings. \n• Integration and Scalability Challenges: Existing systems struggle to integrate \ndata from multiple sources (satellites, sensors, and autonomous vehicles), \nlimiting scalability and adaptability for large-scale ocean monitoring. \nThese challenges highlight the need for self-sustaining, AI-integrated, and IoT-\nenabled AWOS that can autonomously collect, process, and transmit accurate \nmeteorological data in real time'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 11, 'page_label': '12'}, page_content='12 \n \nAIM AND OBJECTIVE(S) OF THE WORK \n \nThe main aim of this seminar is to design, analyze, and evaluate an Automatic \nWeather Observation System (AWOS) capable of autonomously collecting, \nprocessing, and transmitting accurate meteorological data in real time, even \nunder challenging marine and remote conditions. \n \nThe specific objectives are: \n• To develop a fully automated observation system integrating high-precision \nsensors, IoT modules, and satellite communication for continuous weather \nmonitoring. \n• To achieve at least 95% measurement accuracy for key meteorological \nparameters such as temperature, humidity, pressure, and wind speed. \n• To ensure real-time and reliable data transmission using robust wireless or \nsatellite-based networks. \n• To implement AI-based calibration and anomaly detection for maintaining \ndata stability and reducing measurement errors. \n• To support weather forecasting, climate modeling, and disaster \nmanagement through high-resolution, real-time data generation and \nanalysis'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 12, 'page_label': '13'}, page_content='13 \n \n4. METHODOLOGY AND ALGORITHMS  \n \n \nThe proposed Automatic Weather Observation System (AWOS) follows an end-to-\nend autonomous workflow designed to continuously measure, process, and \ntransmit accurate meteorological data from remote ocean environments in real \ntime. \n \n1. Foundational Workflow: \n• Data Acquisition: The system collects real-time atmospheric data such as \ntemperature, pressure, humidity, wind speed, and direction using high-\nprecision marine-grade sensors mounted on buoys or autonomous \nplatforms. Data from satellites, IoT modules, and remote sensing systems \nare also integrated to enhance coverage and accuracy. \n• Preprocessing and Calibration: Sensor data is preprocessed to remove \nnoise, handle missing values, and correct sensor drift. AI-based calibration \nalgorithms adjust sensor readings in real time to maintain over 95% \nmeasurement accuracy even under changing sea conditions. \n• Data Transmission: Preprocessed data is transmitted to the control \nstation via satellite or IoT-based wireless communication. A redundancy \nmechanism ensures reliable data delivery even during poor weather or \nconnectivity loss. \n• Data Analysis and Forecasting: Collected data is processed using machine \nlearning algorithms such as Random Forest, LSTM (Long Short-Term \nMemory), or ARIMA models for trend analysis and short-term weather \nforecasting. These models help predict anomalies like storms or sudden \npressure changes. \n• Data Visualization and Storage: Processed data is stored in cloud servers \nand visualized on monitoring dashboards for researchers, meteorologists, \nand marine authorities.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 13, 'page_label': '14'}, page_content='14 \n \n2. Core Architectural Components: \n• Sensor Subsystem: \nConsists of calibrated sensors for temperature, pressure, humidity, and \nwind speed. Each sensor is enclosed in a waterproof and corrosion-\nresistant housing suitable for marine environments \n• Processing and Control Unit: \nA microcontroller or embedded computing module (e.g., Raspberry Pi or \nARM-based board) performs local data processing, filtering, and \ntransmission control. \n• Communication Module: \nUses satellite (Iridium/Inmarsat) or IoT-based (LoRa/NB-IoT) \ncommunication for real-time data transfer to remote monitoring centers. \n• Power Management System: \nIntegrates solar panels or wave energy converters with smart power \ncontrol circuits to ensure continuous, autonomous operation. \n• AI and Forecasting Engine: \nImplements machine learning models (LSTM, Random Forest) to analyze \ntime-series data for pattern recognition, anomaly detection, and \nforecasting \n \n3. Proposed System Architecture \nThe AWOS architecture integrates sensing, communication, and AI-based analysis \ninto a fully autonomous observation pipeline. \n \nThe system operates as follows: \n1. Sensor Laye: \nCollects raw meteorological data continuously. \n2. Processing Layer: \nPerforms calibration, filtering, and local analysis. \n3. Communication Layer: \nTransmits real-time data to ground or satellite networks. \n4. Cloud & AI Layer: \nAggregates, analyzes, and stores data using ML algorithms.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 14, 'page_label': '15'}, page_content='15 \n \n4.User Interface Layer: \nDisplays live dashboards, alerts, and forecasting insights. \n \n \nFigure 1:Architecture Diagram'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 15, 'page_label': '16'}, page_content='16 \n \n5.User Flow for Data Handling: \n1. Data Upload: \nNew marine data from satellite and bouys are automatically received in an \ninterval of 30 seconds. \n2. Data Conversion: \nA Python script utilizing libraries like xarray converts the uploaded data into \nCSV format for easier manipulation and compatibility with downstream \nprocesses. \n3. Data Storage: \nThe converted data is stored in 2 separate databases. PostgreSQL and FAISS \na vector database. \n4. Data Cleaning: \nThe stored CSV data undergoes preprocessing, including noise removal, \ntypo correction, and normalization to ensure consistency and accuracy. \n5. Data Chunking & Embedding: \nThe cleaned data is divided into smaller, manageable chunks. Each chunk is \nthen transformed into vector embeddings using the open-source model all-\nMiniLM-L6-v2, enabling efficient semantic search and retrieval. \n6. RAG (Retrieval-Augmented Generation) Pipeline: \nBased on the generated embeddings, a RAG pipeline is constructed. This \npipeline retrieves relevant information from the vector database to \ngenerate accurate, context-grounded responses.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 16, 'page_label': '17'}, page_content='17 \n \n \nFig: 2: ML pipeline for data transformation'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 17, 'page_label': '18'}, page_content='18 \n \n \n5. DISCUSSION AND CONCLUSION \n \n \nThe main aim of this project is to design and develop an Automatic Ocean \nObservation System (AWOS) capable of autonomously collecting, analyzing, and \ntransmitting oceanographic data. The system is intended to support marine \nresearch, environmental monitoring, and ecosystem management by providing \nreal-time insights into ocean conditions and biological activity. \n \nReal-life usage in industry or research: \n• Marine Research and Environmental Monitoring: \nAWOS can be deployed by marine research institutions and environmental \nagencies to continuously monitor ocean parameters such as temperature, \nsalinity, and chlorophyll levels. \n• Fisheries and Aquaculture Management: \nThe system assists fisheries departments in tracking plankton density, \nwater quality, and nutrient availability, which are vital for sustainable fish \nfarming and predicting fish population dynamics. \n• Climate and Weather Forecasting Centers: \nNational agencies such as IMD (India Meteorological Department) and \nNOAA can use AWOS data to improve ocean-atmosphere models, cyclone \nprediction, and tsunami early warning systems. \n• Fisheries and Aquaculture Management: \nThe system assists fisheries departments in tracking plankton density, \nwater quality, and nutrient availability, which are vital for sustainable fish \nfarming and predicting fish population dynamics. \n \nScope for extension: \n \n• Real-Time Cloud Analytics: \nIntegrating IoT and cloud platforms for continuous data visualization and \nalert systems.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 18, 'page_label': '19'}, page_content='19 \n \n• Advanced ML Models: \nEmploying deep learning techniques for better species recognition and \nenvironmental forecasting. \n• Energy Optimization: \nIncorporating solar power or renewable energy sources for longer \nautonomous missions. \n• Swarm Coordination: \nDeploying multiple AWOS units that communicate and coordinate for wide-\narea ocean coverage. \n• Global Research Collaboration: \nExpanding the system for use in marine biodiversity studies, climate \nmodeling, and fisheries management worldwide. \n \n \n \nConclusion  \n \nThe Automatic Ocean Observation System (AWOS) represents a major step \nforward in autonomous marine monitoring and data acquisition. By integrating \nadvanced sensors, IoT communication, and AI-driven analytics, AWOS enables \ncontinuous, real-time observation of oceanic conditions with minimal human \nintervention. This technology enhances the accuracy, reliability, and efficiency of \nmarine data collection—supporting climate studies, weather forecasting, and \nsustainable ocean resource management. \n \nWith ongoing innovations in automation, renewable energy integration, and \nintelligent data processing, AWOS systems are poised to become a cornerstone of \nfuture ocean research and environmental monitoring, contributing significantly to \nglobal scientific understanding and sustainable marine development.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 19, 'page_label': '20'}, page_content='20 \n \nREFERENCES \n \n \n• Jie Zhang, Yong Wang, Lihua Zhang, “Ocean Observation Technologies: A \nReview,” Chinese Journal of Mechanical Engineering, 2020. \n \n• Christopher Whitt, Jay Pearlman “Future Vision for Autonomous Ocean \nObservations,” Frontiers in Marine Science, 2020.  \n \n• H. Hemmings et al., “Advanced Sensing Technology for Ocean Observation,” \nPubMed Central, 2025. \n•  \n• C. Sætre et al., “A Smart Ocean Observation System for Reliable Real-Time \nMeasurements,” IEEE OCEANS Conference, 2023.  \n \n• M. C. Sorensen et al., “Collaborative Automation and IoT Technologies for \nCoastal Ocean Observing Systems,” Frontiers in Marine Science, 2021. \n \n• H. Hemmings et al., “Advancing Ocean Observation with an AI-Driven Mobile \nRobotic Explorer,” Oceanography, 2020.')]

# %%
# split documents into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=200 , separators=["\n\n", "\n", " ", ""] , length_function=len)
chunks = text_splitter.split_documents(pages)
chunks[0]
# Out:
# Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-11-06T11:49:19+05:30', 'author': 'HODIT', 'moddate': '2025-11-06T11:49:19+05:30', 'source': 'deepak_seminar.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}, page_content='1 \n \nA Seminar Report \n on \n \n“Automatic Weather Observation System (AWOS)” \n \nSubmitted to the  \nSavitribai Phule Pune University  \nIn partial fulfillment for the award of the Degree of \nBachelor of Engineering  \nin \nInformation Technology \nby \nDeepak Kumar \nRoll No: 4318 \nClass: TE-IT(A)  \n \n \nUnder the guidance of \n \nDr. Ashwini Sapkal \n \nDepartment of Information Technology \nArmy Institute of Technology, \nDighi Hills, Pune - 411 015. \n \n2025-2026')

# %%
def get_embedding():
    embeddings = GoogleGenerativeAIEmbeddings(
        model="gemini-embedding-001",
        api_key=Google_api_key
    )
    return embeddings
embedding_function = get_embedding()

# %%
import uuid
import hashlib
from langchain_community.vectorstores import Chroma

def create_vectorstore(chunks, embedding_function, vectorstore_path="chroma_db"):
    
    def hash_text(text):
        return hashlib.md5(text.encode()).hexdigest()

    # Create unique IDs
    ids = [hash_text(doc.page_content) for doc in chunks]

    unique_chunks = []
    unique_ids = []
    seen = set()

    for chunk, id_ in zip(chunks, ids):
        if id_ not in seen:
            seen.add(id_)
            unique_chunks.append(chunk)
            unique_ids.append(id_)

    # ❗❗ FIXED: use embedding= , NOT embedding_function=
    vectorstore = Chroma.from_documents(
        documents=unique_chunks,
        embedding=embedding_function,     
        ids=unique_ids,
        collection_name="ai_notes",
        persist_directory=vectorstore_path
    )

    vectorstore.persist()
    return vectorstore

# %%
vectorstore = Chroma(
    collection_name="ai_notes",
    persist_directory="chroma_db",
    embedding_function=embedding_function
)

# %%
vectorstore = create_vectorstore(
    chunks=chunks,  
    embedding_function=embedding_function   # ✅ FIXED
)
# Out:
# C:\Users\itsme\AppData\Local\Temp\ipykernel_28460\1302653875.py:32: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectorstore.persist()

# %%
vectorstore = Chroma(
    collection_name="ai_notes",
    persist_directory="chroma_db",
    embedding_function=embedding_function   # ← use this here
)

# %%
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 4}
)

query = "topic of seminar "

relevant_docs = retriever.invoke(query)

for i, doc in enumerate(relevant_docs, start=1):
    print(f"\n---- Result {i} ----")
    print(doc.page_content)
# Out:
# ---- Result 1 ----
# 1
#
# A Seminar Report
#  on
#
# “Automatic Weather Observation System (AWOS)”
#
# Submitted to the
# Savitribai Phule Pune University
# In partial fulfillment for the award of the Degree of
# Bachelor of Engineering
# in
# Information Technology
# by
# Deepak Kumar
# Roll No: 4318
# Class: TE-IT(A)
#
#
# Under the guidance of
#
# Dr. Ashwini Sapkal
#
# Department of Information Technology
# Army Institute of Technology,
# Dighi Hills, Pune - 411 015.
#
# 2025-2026
#
# ---- Result 2 ----
# 11
#
# 3.MOTIVATION, PURPOSE , SCOPE AND
# OBJECTIVE OF SEMINAR
#
#
# MOTIVATION AND PURPOSE (PROBLEM STATEMENT)
# Accurate and continuous weather observation is essential for effective
# forecasting, marine safety, climate research, and disaster preparedness. However,
# traditional observation methods and ground-based systems face major limitations
# in coverage, data consistency, and real-time accessibility
# • Limited Spatial and Temporal Coverage: Conventional observation stations
# are often restricted to land or coastal areas, leaving vast oceanic regions
# unmonitored.
# • Dependence on Manual Operation: Traditional weather monitoring
# requires frequent maintenance and human supervision, making continuous
# data collection difficult in remote or harsh conditions.
# • Data Inaccuracy under Dynamic Conditions: Sea conditions, sensor drift,
# and environmental interference can degrade measurement accuracy over
# time, reducing the reliability of collected data.
# • Lack of Real-Time Data Transmission: Delayed or disrupted communication
# in remote areas prevents timely access to critical weather information
# needed for forecasting and early warnings.
# • Integration and Scalability Challenges: Existing systems struggle to integrate
# data from multiple sources (satellites, sensors, and autonomous vehicles),
# limiting scalability and adaptability for large-scale ocean monitoring.
# These challenges highlight the need for self-sustaining, AI-integrated, and IoT-
#
# ---- Result 3 ----
# 2
#
#
# CERTIFICATE
#
# This is to certify that the seminar report entitled “Automatic Ocean Observation System(AWOS)”
# being submitted by Deepak Kumar  (4318 / TE-IT(A)) is a record of bonafide work carried out by
# him/her under the supervision and guidance of Dr. Ashwini Sapkal in partial fulfillment of the
# requirement for TE (Information Technology Engineering) – 2019 course of Savitribai Phule Pune
# University, Pune in the academic year 2025-2026.
#
# Date:
#
# Place: Pune
#
#
#
#
#
#
#              Guide                                                 Head of the Department
#
#
#
#
# Principal
#
#
# This Seminar report has been examined by us as per the Savitribai Phule Pune University, Pune
# requirements at Army Institute of Technology, Pune – 411015 on . . . . . . . . . . .
#
#
#
# Internal
# Examiner
#                                                                                  External
# Examiner
#
# ---- Result 4 ----
# 12
#
# AIM AND OBJECTIVE(S) OF THE WORK
#
# The main aim of this seminar is to design, analyze, and evaluate an Automatic
# Weather Observation System (AWOS) capable of autonomously collecting,
# processing, and transmitting accurate meteorological data in real time, even
# under challenging marine and remote conditions.
#
# The specific objectives are:
# • To develop a fully automated observation system integrating high-precision
# sensors, IoT modules, and satellite communication for continuous weather
# monitoring.
# • To achieve at least 95% measurement accuracy for key meteorological
# parameters such as temperature, humidity, pressure, and wind speed.
# • To ensure real-time and reliable data transmission using robust wireless or
# satellite-based networks.
# • To implement AI-based calibration and anomaly detection for maintaining
# data stability and reducing measurement errors.
# • To support weather forecasting, climate modeling, and disaster
# management through high-resolution, real-time data generation and
# analysis

# %%
PROMPT_TEMPLATE = """
You are an assistant for a question-answering task.
Use the following pieces of retrieved context to answer the question.
If you do not know the answer, say "I don't know" — do not make up an answer.
If the question is not related to the context, politely say that you can answer only context-related questions.

=== Retrieved Context ===
{context}

---

Answer the question: {question}
"""

# %%
content_text = "\n\n".join([doc.page_content for doc in relevant_docs])

prompt_template = PromptTemplate(
    input_variables=["context", "question"],
    template=PROMPT_TEMPLATE
)

prompt = prompt_template.format(
    context=content_text,
    question=query
)

# %%
response = llm.invoke(prompt)
print(response)
# Out:
# content='The topic of the seminar is "Automatic Weather Observation System (AWOS)".' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--e374e76f-1f99-4deb-93f0-c96644ab8f8e-0' usage_metadata={'input_tokens': 1027, 'output_tokens': 436, 'total_tokens': 1463, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 421}}
